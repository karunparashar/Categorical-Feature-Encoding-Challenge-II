# %%
import pandas as pd
df = pd.read_csv('train.csv')
df
# Out:
#             id  bin_0  bin_1  bin_2 bin_3 bin_4  nom_0      nom_1    nom_2  \
# 0            0    0.0    0.0    0.0     F     N    Red  Trapezoid  Hamster
# 1            1    1.0    1.0    0.0     F     Y    Red       Star  Axolotl
# 2            2    0.0    1.0    0.0     F     N    Red        NaN  Hamster
# 3            3    NaN    0.0    0.0     F     N    Red     Circle  Hamster
# 4            4    0.0    NaN    0.0     T     N    Red   Triangle  Hamster
# 5            5    0.0    NaN    1.0     T     N    Red   Triangle     Lion
# 6            6    0.0    0.0    0.0     F     N    Red   Triangle  Hamster
# 7            7    0.0    0.0    1.0     T     N    Red   Triangle  Axolotl
# 8            8    0.0    0.0    0.0     F     N   Blue    Polygon  Hamster
# 9            9    0.0    0.0    NaN     F     Y    Red    Polygon  Hamster
# 10          10    0.0    0.0    1.0     T     Y   Blue   Triangle  Hamster
# 11          11    0.0    0.0    1.0     F     Y    Red     Square  Hamster
# 12          12    0.0    0.0    0.0     T   NaN    Red     Circle  Axolotl
# 13          13    0.0    1.0    0.0     F     N   Blue  Trapezoid     Lion
# 14          14    0.0    0.0    0.0     F     Y    Red    Polygon  Hamster
# 15          15    1.0    0.0    NaN     F   NaN    Red    Polygon  Hamster
# 16          16    0.0    0.0    0.0     F     Y    Red   Triangle     Lion
# 17          17    NaN    1.0    1.0     F     N    Red  Trapezoid  Hamster
# 18          18    1.0    0.0    0.0     F     Y    Red     Circle  Axolotl
# 19          19    0.0    1.0    0.0     F     Y    Red   Triangle  Hamster
# 20          20    0.0    0.0    0.0     T     N   Blue   Triangle      Dog
# 21          21    1.0    1.0    0.0     F     N    Red   Triangle      Cat
# 22          22    0.0    0.0    0.0   NaN     N  Green     Circle  Hamster
# 23          23    0.0    0.0    0.0     T     N    Red    Polygon  Hamster
# 24          24    0.0    1.0    1.0     F     Y    Red     Circle  Hamster
# 25          25    0.0    0.0    0.0   NaN     Y   Blue     Circle      Dog
# 26          26    0.0    1.0    0.0     F     N   Blue     Circle     Lion
# 27          27    0.0    0.0    0.0     F     N    Red     Circle  Axolotl
# 28          28    0.0    0.0    0.0     F     N  Green        NaN     Lion
# 29          29    0.0    NaN    1.0     F     Y   Blue     Square     Lion
# ...        ...    ...    ...    ...   ...   ...    ...        ...      ...
# 599970  599970    NaN    1.0    0.0     F     Y   Blue    Polygon     Lion
# 599971  599971    NaN    0.0    1.0     F     N    Red   Triangle  Axolotl
# 599972  599972    0.0    0.0    0.0   NaN     Y    Red    Polygon      Dog
# 599973  599973    1.0    0.0    0.0     F     Y   Blue   Triangle  Hamster
# 599974  599974    0.0    1.0    0.0     T     Y    Red   Triangle     Lion
# 599975  599975    0.0    0.0    0.0     F   NaN   Blue  Trapezoid  Hamster
# 599976  599976    0.0    0.0    1.0     F     N    Red   Triangle  Hamster
# 599977  599977    0.0    1.0    0.0     F     N   Blue     Square  Hamster
# 599978  599978    0.0    1.0    0.0     T     Y   Blue     Circle      Dog
# 599979  599979    0.0    0.0    0.0     T     Y  Green     Square     Lion
# 599980  599980    0.0    1.0    0.0     F   NaN    Red     Square  Hamster
# 599981  599981    0.0    0.0    0.0     T     Y    NaN     Circle  Hamster
# 599982  599982    1.0    0.0    1.0     T     Y   Blue  Trapezoid      Cat
# 599983  599983    NaN    0.0    0.0     F     Y    Red    Polygon  Axolotl
# 599984  599984    0.0    0.0    0.0     F     N    Red   Triangle      Dog
# 599985  599985    0.0    0.0    0.0     F     Y   Blue   Triangle  Hamster
# 599986  599986    0.0    0.0    0.0     F     Y   Blue    Polygon  Axolotl
# 599987  599987    NaN    0.0    1.0     T     N    Red        NaN      Dog
# 599988  599988    0.0    1.0    1.0     F     N    Red   Triangle     Lion
# 599989  599989    0.0    0.0    0.0     F     Y   Blue     Circle  Axolotl
# 599990  599990    0.0    0.0    1.0     F     Y    Red    Polygon  Axolotl
# 599991  599991    1.0    0.0    0.0     T     N   Blue   Triangle     Lion
# 599992  599992    1.0    0.0    0.0     T     N   Blue  Trapezoid  Hamster
# 599993  599993    0.0    1.0    0.0     F     N  Green   Triangle      Dog
# 599994  599994    0.0    0.0    0.0     T     Y    Red   Triangle      NaN
# 599995  599995    0.0    1.0    0.0     T     N    Red    Polygon  Axolotl
# 599996  599996    1.0    0.0    0.0     T     Y   Blue    Polygon      Dog
# 599997  599997    0.0    0.0    0.0     F     Y    Red     Circle  Axolotl
# 599998  599998    1.0    1.0    0.0     F     Y    NaN    Polygon  Axolotl
# 599999  599999    0.0    0.0    0.0     T     N   Blue   Triangle      Dog
#
#              nom_3  ...      nom_9 ord_0        ord_1        ord_2 ord_3  \
# 0           Russia  ...  02e7c8990   3.0  Contributor          Hot     c
# 1              NaN  ...  f37df64af   3.0  Grandmaster         Warm     e
# 2           Canada  ...        NaN   3.0          NaN     Freezing     n
# 3          Finland  ...  f9d456e57   1.0       Novice     Lava Hot     a
# 4       Costa Rica  ...  c5361037c   3.0  Grandmaster         Cold     h
# 5            China  ...  05afc0f8b   2.0       Expert          Hot     b
# 6       Costa Rica  ...  4d3766412   1.0  Grandmaster         Cold     c
# 7          Finland  ...  a651dec43   3.0       Expert         Cold     b
# 8           Russia  ...        NaN   1.0       Novice  Boiling Hot     c
# 9          Finland  ...  79b29d54c   3.0  Contributor     Lava Hot     n
# 10         Finland  ...  9bfe3ee22   1.0       Novice          Hot     b
# 11      Costa Rica  ...  6c73b62e4   1.0  Contributor          Hot     b
# 12          Russia  ...  ed7765a22   3.0       Novice     Freezing     a
# 13      Costa Rica  ...  fb68fb0cf   3.0  Contributor     Lava Hot     h
# 14      Costa Rica  ...  e23161f2e   2.0       Master     Freezing     d
# 15          Russia  ...  e5260d8ba   2.0  Contributor          Hot     k
# 16      Costa Rica  ...  99f6dca00   1.0       Novice  Boiling Hot     h
# 17          Russia  ...  bc5c8fe51   3.0       Novice         Warm     g
# 18           India  ...  bf2a46c9a   3.0       Master          Hot     h
# 19      Costa Rica  ...  602d7a9af   1.0  Grandmaster  Boiling Hot     n
# 20           India  ...  7df225ca0   3.0       Novice     Freezing     h
# 21          Canada  ...  dfaef9aac   3.0  Contributor          Hot     h
# 22          Canada  ...  7f228b10f   2.0       Master          Hot     k
# 23           India  ...  d7b264c91   1.0       Novice         Warm     n
# 24           India  ...  1bb10e6ca   1.0  Grandmaster  Boiling Hot     b
# 25          Canada  ...  85334bf6e   1.0       Expert         Warm     c
# 26           India  ...  d518a193a   3.0  Grandmaster     Freezing     o
# 27      Costa Rica  ...  1c61b1687   1.0       Novice         Cold     a
# 28      Costa Rica  ...  2efbc0f39   1.0       Novice         Warm     a
# 29           India  ...  5e7d3277d   1.0       Expert         Cold     a
# ...            ...  ...        ...   ...          ...          ...   ...
# 599970      Russia  ...  20d0da77a   2.0  Contributor     Freezing     a
# 599971     Finland  ...  34ba0668d   2.0  Contributor     Freezing     a
# 599972  Costa Rica  ...  c9a07c607   3.0  Grandmaster     Freezing     d
# 599973  Costa Rica  ...  dbeabb21e   3.0  Contributor         Cold     h
# 599974  Costa Rica  ...  b375cf3bf   1.0       Master  Boiling Hot     d
# 599975     Finland  ...  f6f9e1419   2.0       Expert     Freezing     n
# 599976      Russia  ...  49d2f3324   3.0  Grandmaster     Lava Hot     h
# 599977  Costa Rica  ...  c9a07c607   3.0       Novice          Hot     n
# 599978     Finland  ...  b3e0fdd5f   3.0  Contributor     Freezing     f
# 599979       China  ...  10eb91ed6   2.0       Expert  Boiling Hot     d
# 599980  Costa Rica  ...  cad7c3e71   1.0       Master          Hot     o
# 599981  Costa Rica  ...  c9d78c188   3.0  Contributor     Lava Hot     c
# 599982       India  ...        NaN   2.0  Contributor         Warm     n
# 599983     Finland  ...  a69c0c607   3.0       Expert         Cold     c
# 599984      Russia  ...  311a53c9d   3.0       Novice     Freezing     c
# 599985  Costa Rica  ...  fd18dcbc5   3.0       Novice         Warm     h
# 599986     Finland  ...  49bc9f29c   2.0       Expert     Freezing     k
# 599987     Finland  ...  9660c9e92   2.0       Novice         Warm     d
# 599988       India  ...  ff4a11ad3   2.0       Master     Lava Hot     k
# 599989      Russia  ...  f4446f807   3.0       Master  Boiling Hot     k
# 599990       India  ...  411d37ac3   1.0       Novice     Freezing     i
# 599991       India  ...  2afbf5e88   3.0  Contributor         Warm     f
# 599992  Costa Rica  ...  57934b610   2.0       Novice     Freezing     d
# 599993      Russia  ...  a36361110   3.0  Contributor     Freezing     n
# 599994       China  ...  b04d90dad   3.0  Grandmaster         Cold     f
# 599995       India  ...  015c63324   3.0       Novice     Freezing     a
# 599996  Costa Rica  ...  a02ae6a63   2.0       Novice  Boiling Hot     n
# 599997      Russia  ...  40f9610c1   2.0  Contributor     Freezing     n
# 599998         NaN  ...  c1a8374a0   1.0       Master         Warm     m
# 599999      Russia  ...  e2aea7784   1.0  Contributor  Boiling Hot     b
#
#        ord_4  ord_5  day month target
# 0          U     Pw  6.0   3.0      0
# 1          X     pE  7.0   7.0      0
# 2          P     eN  5.0   9.0      0
# 3          C    NaN  3.0   3.0      0
# 4          C     OZ  5.0  12.0      0
# 5          Q     wa  3.0   4.0      0
# 6          R     rg  5.0   6.0      0
# 7          Y     PS  1.0   1.0      0
# 8          N     mX  6.0   3.0      0
# 9          I     OZ  1.0   8.0      1
# 10         O     hG  7.0   5.0      1
# 11         M     xF  2.0   8.0      0
# 12         Y     RV  3.0   5.0      0
# 13         C     Nh  6.0   3.0      0
# 14         Y     dp  2.0   8.0      0
# 15         P     SS  1.0  11.0      0
# 16         E    NaN  6.0   7.0      0
# 17         I     OM  7.0   5.0      1
# 18         V     Rv  NaN   3.0      1
# 19         K     HF  6.0  12.0      0
# 20         E     RV  7.0  11.0      0
# 21         N     iS  7.0   8.0      0
# 22         G     HK  5.0  12.0      0
# 23         K     hG  4.0   NaN      0
# 24         B     Ib  6.0   4.0      0
# 25         H     AW  3.0   3.0      0
# 26         O     mi  2.0  11.0      0
# 27         I     jf  5.0   8.0      0
# 28       NaN     Tz  7.0   4.0      0
# 29         U     ok  5.0   8.0      0
# ...      ...    ...  ...   ...    ...
# 599970     O     kv  3.0   6.0      0
# 599971     N     oU  2.0   6.0      0
# 599972     U     IA  2.0   6.0      0
# 599973     N     Bx  3.0   3.0      0
# 599974     W     dh  1.0   8.0      0
# 599975     E     rl  3.0   9.0      0
# 599976     O     Rv  1.0   1.0      1
# 599977     K     Ji  3.0   3.0      0
# 599978     T     Re  6.0   6.0      0
# 599979     D     HK  6.0   1.0      0
# 599980     T     rA  3.0  12.0      1
# 599981     T     cR  7.0   6.0      0
# 599982     K     Rv  3.0   2.0      0
# 599983     M     oh  5.0   5.0      0
# 599984     X     Rz  3.0   2.0      0
# 599985     M     xG  1.0   5.0      0
# 599986     G     Kq  7.0   9.0      0
# 599987     C     WW  3.0  11.0      0
# 599988     P    NaN  3.0   8.0      0
# 599989     W     eN  7.0   2.0      1
# 599990     E     DI  1.0   5.0      0
# 599991     T     dp  1.0   8.0      0
# 599992     K     xF  7.0  12.0      0
# 599993     T     iv  7.0  12.0      0
# 599994     F     dp  3.0  11.0      0
# 599995     R     GZ  5.0   NaN      0
# 599996     N     sf  NaN   3.0      0
# 599997     H     MV  7.0   5.0      0
# 599998     X     Ey  1.0   5.0      0
# 599999     O     uI  5.0   8.0      0
#
# [600000 rows x 25 columns]

# %%
print(df.shape)

# %%
#5 binary,10 nominal,6 ordinal
#null values
col_names= list(df.columns)
col_names
em=[]
nd = {}
# df.iloc[:,1]
for i in col_names:
    if sum(df[i].isnull())>0:
        nd[i] = sum(df[i].isnull())
# nd

# %%
#unique values
ne ={}
for i in col_names:
    if sum(df[i].isnull())>0:
        ne[i] = len(df[i].unique())
# ne

# %%
columns_to_use= list(df.columns)
col2remove= ["nom_5","nom_6","nom_7","nom_8","nom_9","ord_5"]
cols =[]
for i in columns_to_use:
    if i not in col2remove:
        cols.append(i)
df2 = pd.DataFrame()
for i in cols:
    df2[i] = df[i]
df2
# Out:
#             id  bin_0  bin_1  bin_2 bin_3 bin_4  nom_0      nom_1    nom_2  \
# 0            0    0.0    0.0    0.0     F     N    Red  Trapezoid  Hamster
# 1            1    1.0    1.0    0.0     F     Y    Red       Star  Axolotl
# 2            2    0.0    1.0    0.0     F     N    Red        NaN  Hamster
# 3            3    NaN    0.0    0.0     F     N    Red     Circle  Hamster
# 4            4    0.0    NaN    0.0     T     N    Red   Triangle  Hamster
# 5            5    0.0    NaN    1.0     T     N    Red   Triangle     Lion
# 6            6    0.0    0.0    0.0     F     N    Red   Triangle  Hamster
# 7            7    0.0    0.0    1.0     T     N    Red   Triangle  Axolotl
# 8            8    0.0    0.0    0.0     F     N   Blue    Polygon  Hamster
# 9            9    0.0    0.0    NaN     F     Y    Red    Polygon  Hamster
# 10          10    0.0    0.0    1.0     T     Y   Blue   Triangle  Hamster
# 11          11    0.0    0.0    1.0     F     Y    Red     Square  Hamster
# 12          12    0.0    0.0    0.0     T   NaN    Red     Circle  Axolotl
# 13          13    0.0    1.0    0.0     F     N   Blue  Trapezoid     Lion
# 14          14    0.0    0.0    0.0     F     Y    Red    Polygon  Hamster
# 15          15    1.0    0.0    NaN     F   NaN    Red    Polygon  Hamster
# 16          16    0.0    0.0    0.0     F     Y    Red   Triangle     Lion
# 17          17    NaN    1.0    1.0     F     N    Red  Trapezoid  Hamster
# 18          18    1.0    0.0    0.0     F     Y    Red     Circle  Axolotl
# 19          19    0.0    1.0    0.0     F     Y    Red   Triangle  Hamster
# 20          20    0.0    0.0    0.0     T     N   Blue   Triangle      Dog
# 21          21    1.0    1.0    0.0     F     N    Red   Triangle      Cat
# 22          22    0.0    0.0    0.0   NaN     N  Green     Circle  Hamster
# 23          23    0.0    0.0    0.0     T     N    Red    Polygon  Hamster
# 24          24    0.0    1.0    1.0     F     Y    Red     Circle  Hamster
# 25          25    0.0    0.0    0.0   NaN     Y   Blue     Circle      Dog
# 26          26    0.0    1.0    0.0     F     N   Blue     Circle     Lion
# 27          27    0.0    0.0    0.0     F     N    Red     Circle  Axolotl
# 28          28    0.0    0.0    0.0     F     N  Green        NaN     Lion
# 29          29    0.0    NaN    1.0     F     Y   Blue     Square     Lion
# ...        ...    ...    ...    ...   ...   ...    ...        ...      ...
# 599970  599970    NaN    1.0    0.0     F     Y   Blue    Polygon     Lion
# 599971  599971    NaN    0.0    1.0     F     N    Red   Triangle  Axolotl
# 599972  599972    0.0    0.0    0.0   NaN     Y    Red    Polygon      Dog
# 599973  599973    1.0    0.0    0.0     F     Y   Blue   Triangle  Hamster
# 599974  599974    0.0    1.0    0.0     T     Y    Red   Triangle     Lion
# 599975  599975    0.0    0.0    0.0     F   NaN   Blue  Trapezoid  Hamster
# 599976  599976    0.0    0.0    1.0     F     N    Red   Triangle  Hamster
# 599977  599977    0.0    1.0    0.0     F     N   Blue     Square  Hamster
# 599978  599978    0.0    1.0    0.0     T     Y   Blue     Circle      Dog
# 599979  599979    0.0    0.0    0.0     T     Y  Green     Square     Lion
# 599980  599980    0.0    1.0    0.0     F   NaN    Red     Square  Hamster
# 599981  599981    0.0    0.0    0.0     T     Y    NaN     Circle  Hamster
# 599982  599982    1.0    0.0    1.0     T     Y   Blue  Trapezoid      Cat
# 599983  599983    NaN    0.0    0.0     F     Y    Red    Polygon  Axolotl
# 599984  599984    0.0    0.0    0.0     F     N    Red   Triangle      Dog
# 599985  599985    0.0    0.0    0.0     F     Y   Blue   Triangle  Hamster
# 599986  599986    0.0    0.0    0.0     F     Y   Blue    Polygon  Axolotl
# 599987  599987    NaN    0.0    1.0     T     N    Red        NaN      Dog
# 599988  599988    0.0    1.0    1.0     F     N    Red   Triangle     Lion
# 599989  599989    0.0    0.0    0.0     F     Y   Blue     Circle  Axolotl
# 599990  599990    0.0    0.0    1.0     F     Y    Red    Polygon  Axolotl
# 599991  599991    1.0    0.0    0.0     T     N   Blue   Triangle     Lion
# 599992  599992    1.0    0.0    0.0     T     N   Blue  Trapezoid  Hamster
# 599993  599993    0.0    1.0    0.0     F     N  Green   Triangle      Dog
# 599994  599994    0.0    0.0    0.0     T     Y    Red   Triangle      NaN
# 599995  599995    0.0    1.0    0.0     T     N    Red    Polygon  Axolotl
# 599996  599996    1.0    0.0    0.0     T     Y   Blue    Polygon      Dog
# 599997  599997    0.0    0.0    0.0     F     Y    Red     Circle  Axolotl
# 599998  599998    1.0    1.0    0.0     F     Y    NaN    Polygon  Axolotl
# 599999  599999    0.0    0.0    0.0     T     N   Blue   Triangle      Dog
#
#              nom_3     nom_4  ord_0        ord_1        ord_2 ord_3 ord_4  \
# 0           Russia   Bassoon    3.0  Contributor          Hot     c     U
# 1              NaN  Theremin    3.0  Grandmaster         Warm     e     X
# 2           Canada   Bassoon    3.0          NaN     Freezing     n     P
# 3          Finland  Theremin    1.0       Novice     Lava Hot     a     C
# 4       Costa Rica       NaN    3.0  Grandmaster         Cold     h     C
# 5            China   Bassoon    2.0       Expert          Hot     b     Q
# 6       Costa Rica   Bassoon    1.0  Grandmaster         Cold     c     R
# 7          Finland   Bassoon    3.0       Expert         Cold     b     Y
# 8           Russia      Oboe    1.0       Novice  Boiling Hot     c     N
# 9          Finland  Theremin    3.0  Contributor     Lava Hot     n     I
# 10         Finland   Bassoon    1.0       Novice          Hot     b     O
# 11      Costa Rica      Oboe    1.0  Contributor          Hot     b     M
# 12          Russia  Theremin    3.0       Novice     Freezing     a     Y
# 13      Costa Rica   Bassoon    3.0  Contributor     Lava Hot     h     C
# 14      Costa Rica     Piano    2.0       Master     Freezing     d     Y
# 15          Russia   Bassoon    2.0  Contributor          Hot     k     P
# 16      Costa Rica   Bassoon    1.0       Novice  Boiling Hot     h     E
# 17          Russia   Bassoon    3.0       Novice         Warm     g     I
# 18           India      Oboe    3.0       Master          Hot     h     V
# 19      Costa Rica  Theremin    1.0  Grandmaster  Boiling Hot     n     K
# 20           India   Bassoon    3.0       Novice     Freezing     h     E
# 21          Canada   Bassoon    3.0  Contributor          Hot     h     N
# 22          Canada  Theremin    2.0       Master          Hot     k     G
# 23           India   Bassoon    1.0       Novice         Warm     n     K
# 24           India  Theremin    1.0  Grandmaster  Boiling Hot     b     B
# 25          Canada      Oboe    1.0       Expert         Warm     c     H
# 26           India      Oboe    3.0  Grandmaster     Freezing     o     O
# 27      Costa Rica   Bassoon    1.0       Novice         Cold     a     I
# 28      Costa Rica  Theremin    1.0       Novice         Warm     a   NaN
# 29           India       NaN    1.0       Expert         Cold     a     U
# ...            ...       ...    ...          ...          ...   ...   ...
# 599970      Russia  Theremin    2.0  Contributor     Freezing     a     O
# 599971     Finland      Oboe    2.0  Contributor     Freezing     a     N
# 599972  Costa Rica  Theremin    3.0  Grandmaster     Freezing     d     U
# 599973  Costa Rica   Bassoon    3.0  Contributor         Cold     h     N
# 599974  Costa Rica   Bassoon    1.0       Master  Boiling Hot     d     W
# 599975     Finland   Bassoon    2.0       Expert     Freezing     n     E
# 599976      Russia   Bassoon    3.0  Grandmaster     Lava Hot     h     O
# 599977  Costa Rica  Theremin    3.0       Novice          Hot     n     K
# 599978     Finland   Bassoon    3.0  Contributor     Freezing     f     T
# 599979       China      Oboe    2.0       Expert  Boiling Hot     d     D
# 599980  Costa Rica   Bassoon    1.0       Master          Hot     o     T
# 599981  Costa Rica  Theremin    3.0  Contributor     Lava Hot     c     T
# 599982       India  Theremin    2.0  Contributor         Warm     n     K
# 599983     Finland  Theremin    3.0       Expert         Cold     c     M
# 599984      Russia  Theremin    3.0       Novice     Freezing     c     X
# 599985  Costa Rica      Oboe    3.0       Novice         Warm     h     M
# 599986     Finland     Piano    2.0       Expert     Freezing     k     G
# 599987     Finland  Theremin    2.0       Novice         Warm     d     C
# 599988       India  Theremin    2.0       Master     Lava Hot     k     P
# 599989      Russia   Bassoon    3.0       Master  Boiling Hot     k     W
# 599990       India  Theremin    1.0       Novice     Freezing     i     E
# 599991       India     Piano    3.0  Contributor         Warm     f     T
# 599992  Costa Rica  Theremin    2.0       Novice     Freezing     d     K
# 599993      Russia   Bassoon    3.0  Contributor     Freezing     n     T
# 599994       China  Theremin    3.0  Grandmaster         Cold     f     F
# 599995       India  Theremin    3.0       Novice     Freezing     a     R
# 599996  Costa Rica      Oboe    2.0       Novice  Boiling Hot     n     N
# 599997      Russia  Theremin    2.0  Contributor     Freezing     n     H
# 599998         NaN     Piano    1.0       Master         Warm     m     X
# 599999      Russia  Theremin    1.0  Contributor  Boiling Hot     b     O
#
#         day  month  target
# 0       6.0    3.0       0
# 1       7.0    7.0       0
# 2       5.0    9.0       0
# 3       3.0    3.0       0
# 4       5.0   12.0       0
# 5       3.0    4.0       0
# 6       5.0    6.0       0
# 7       1.0    1.0       0
# 8       6.0    3.0       0
# 9       1.0    8.0       1
# 10      7.0    5.0       1
# 11      2.0    8.0       0
# 12      3.0    5.0       0
# 13      6.0    3.0       0
# 14      2.0    8.0       0
# 15      1.0   11.0       0
# 16      6.0    7.0       0
# 17      7.0    5.0       1
# 18      NaN    3.0       1
# 19      6.0   12.0       0
# 20      7.0   11.0       0
# 21      7.0    8.0       0
# 22      5.0   12.0       0
# 23      4.0    NaN       0
# 24      6.0    4.0       0
# 25      3.0    3.0       0
# 26      2.0   11.0       0
# 27      5.0    8.0       0
# 28      7.0    4.0       0
# 29      5.0    8.0       0
# ...     ...    ...     ...
# 599970  3.0    6.0       0
# 599971  2.0    6.0       0
# 599972  2.0    6.0       0
# 599973  3.0    3.0       0
# 599974  1.0    8.0       0
# 599975  3.0    9.0       0
# 599976  1.0    1.0       1
# 599977  3.0    3.0       0
# 599978  6.0    6.0       0
# 599979  6.0    1.0       0
# 599980  3.0   12.0       1
# 599981  7.0    6.0       0
# 599982  3.0    2.0       0
# 599983  5.0    5.0       0
# 599984  3.0    2.0       0
# 599985  1.0    5.0       0
# 599986  7.0    9.0       0
# 599987  3.0   11.0       0
# 599988  3.0    8.0       0
# 599989  7.0    2.0       1
# 599990  1.0    5.0       0
# 599991  1.0    8.0       0
# 599992  7.0   12.0       0
# 599993  7.0   12.0       0
# 599994  3.0   11.0       0
# 599995  5.0    NaN       0
# 599996  NaN    3.0       0
# 599997  7.0    5.0       0
# 599998  1.0    5.0       0
# 599999  5.0    8.0       0
#
# [600000 rows x 19 columns]

# %%
nf ={}
for i in cols:
    if sum(df2[i].isnull())>0:
        nf[i] = list(df2[i].unique())
nf

# %%
#replacing NA with the most frequent value in that column
import statistics
df2.bin_0.fillna(statistics.mode(df2.bin_0),inplace=True)
for i in cols:
    if sum(df2[i].isnull())!=0:
        df2[i].fillna(statistics.mode(df2[i]),inplace=True)

# sum(df2.bin_0.isnull())

# %%
# df2.iloc[:,18]
# df2.iloc[:,0:18]

# %%
from sklearn.model_selection import train_test_split
# df_dummy.columns

df_x = df2.iloc[:,0:18]
df_y = df2.iloc[:,18]

x_train, x_test, y_train, y_test = train_test_split(df_x,df_y,
                                                    train_size=0.8,test_size=0.2,
                                                    random_state = 7)

# nf2 ={}
# for i in cols:
#     if sum(df2[i].isnull())>0:
#         nf2[i] = list(df2[i].unique())

# nf2

# %%
h2o.init(max_mem_size = "5g")
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
# ---------------------------------------------------------------------------
# H2OConnectionError                        Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/h2o/h2o.py in init(url, ip, port, name, https, cacert, insecure, username, password, cookies, proxy, start_h2o, nthreads, ice_root, log_dir, log_level, enable_assertions, max_mem_size, min_mem_size, strict_version_check, ignore_config, extra_classpath, jvm_custom_args, bind_to_localhost, **kwargs)
#     300                                      auth=auth, proxy=proxy,cookies=cookies, verbose=True,
# --> 301                                      _msgs=("Checking whether there is an H2O instance running at {url} ",
#     302                                             "connected.", "not found."))
#
# //anaconda3/lib/python3.7/site-packages/h2o/backend/connection.py in open(server, url, ip, port, name, https, auth, verify_ssl_certificates, cacert, proxy, cookies, verbose, _msgs)
#     383             conn._timeout = 3.0
# --> 384             conn._cluster = conn._test_connection(retries, messages=_msgs)
#     385             # If a server is unable to respond within 1s, it should be considered a bug. However we disable this
#
# //anaconda3/lib/python3.7/site-packages/h2o/backend/connection.py in _test_connection(self, max_retries, messages)
#     683             raise H2OConnectionError("Could not establish link to the H2O cloud %s after %d retries\n%s"
# --> 684                                      % (self._base_url, max_retries, "\n".join(errors)))
#     685
#
# H2OConnectionError: Could not establish link to the H2O cloud http://localhost:54321 after 5 retries
# [12:35.84] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Cloud (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1241c6048>: Failed to establish a new connection: [Errno 61] Connection refused'))
# [12:36.06] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Cloud (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1241ee518>: Failed to establish a new connection: [Errno 61] Connection refused'))
# [12:36.27] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Cloud (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1241ff390>: Failed to establish a new connection: [Errno 61] Connection refused'))
# [12:36.49] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Cloud (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1241ffc88>: Failed to establish a new connection: [Errno 61] Connection refused'))
# [12:36.70] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Cloud (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x1241ee240>: Failed to establish a new connection: [Errno 61] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-40-0d0d4a338d04> in <module>
# ----> 1 h2o.init(max_mem_size = "5g")
#
# //anaconda3/lib/python3.7/site-packages/h2o/h2o.py in init(url, ip, port, name, https, cacert, insecure, username, password, cookies, proxy, start_h2o, nthreads, ice_root, log_dir, log_level, enable_assertions, max_mem_size, min_mem_size, strict_version_check, ignore_config, extra_classpath, jvm_custom_args, bind_to_localhost, **kwargs)
#     312                                   port=port, name=name,
#     313                                   extra_classpath=extra_classpath, jvm_custom_args=jvm_custom_args,
# --> 314                                   bind_to_localhost=bind_to_localhost)
#     315         h2oconn = H2OConnection.open(server=hs, https=https, verify_ssl_certificates=verify_ssl_certificates,
#     316                                      cacert=cacert, auth=auth, proxy=proxy,cookies=cookies, verbose=True)
#
# //anaconda3/lib/python3.7/site-packages/h2o/backend/server.py in start(jar_path, nthreads, enable_assertions, max_mem_size, min_mem_size, ice_root, log_dir, log_level, port, name, extra_classpath, verbose, jvm_custom_args, bind_to_localhost)
#     138         hs._launch_server(port=port, baseport=baseport, nthreads=int(nthreads), ea=enable_assertions,
#     139                           mmax=max_mem_size, mmin=min_mem_size, jvm_custom_args=jvm_custom_args,
# --> 140                           bind_to_localhost=bind_to_localhost, log_dir=log_dir, log_level=log_level)
#     141         if verbose: print("  Server is running at %s://%s:%d" % (hs.scheme, hs.ip, hs.port))
#     142         atexit.register(lambda: hs.shutdown())
#
# //anaconda3/lib/python3.7/site-packages/h2o/backend/server.py in _launch_server(self, port, baseport, mmax, mmin, ea, nthreads, jvm_custom_args, bind_to_localhost, log_dir, log_level)
#     272         # Find Java and check version. (Note that subprocess.check_output returns the output as a bytes object)
#     273         java = self._find_java()
# --> 274         self._check_java(java, self._verbose)
#     275
#     276         if self._verbose:
#
# //anaconda3/lib/python3.7/site-packages/h2o/backend/server.py in _check_java(java, verbose)
#     369     @staticmethod
#     370     def _check_java(java, verbose):
# --> 371         jver_bytes = subprocess.check_output([java, "-version"], stderr=subprocess.STDOUT)
#     372         jver = jver_bytes.decode(encoding="utf-8", errors="ignore")
#     373         if verbose:
#
# //anaconda3/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     393
#     394     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 395                **kwargs).stdout
#     396
#     397
#
# //anaconda3/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     485         if check and retcode:
#     486             raise CalledProcessError(retcode, process.args,
# --> 487                                      output=stdout, stderr=stderr)
#     488     return CompletedProcess(process.args, retcode, stdout, stderr)
#     489
#
# CalledProcessError: Command '['/usr/bin/java', '-version']' returned non-zero exit status 1.

# %%
# Input parameters that are going to train
training_columns = [df2.iloc[:,0:18].columns]
# Output parameter train against input parameters
response_column = 'target'
train, test = h2o.s
import h2o
from h2o.estimators import H2ORandomForestEstimator
model_RF = H2ORandomForestEstimator(ntrees=50, max_depth=20, nfolds=10)
RF_mod = model_RF.train(x=training_columns,y=response_column, training_frame=df_x)
# from sklearn.tree import DecisionTreeClassifier
# RF_H = DecisionTreeClassifier()
# DT_model = DT_m.fit(df_x,df_y)
# Out:
# ---------------------------------------------------------------------------
# H2OTypeError                              Traceback (most recent call last)
# <ipython-input-35-a7b4cc13780c> in <module>
#       7 from h2o.estimators import H2ORandomForestEstimator
#       8 model_RF = H2ORandomForestEstimator(ntrees=50, max_depth=20, nfolds=10)
# ----> 9 RF_mod = model_RF.train(x=training_columns,y=response_column, training_frame=df_x)
#      10 # from sklearn.tree import DecisionTreeClassifier
#      11 # RF_H = DecisionTreeClassifier()
#
# //anaconda3/lib/python3.7/site-packages/h2o/estimators/estimator_base.py in train(self, x, y, training_frame, offset_column, fold_column, weights_column, validation_frame, max_runtime_secs, ignored_columns, model_id, verbose)
#     110         self._train(x=x, y=y, training_frame=training_frame, offset_column=offset_column, fold_column=fold_column,
#     111                     weights_column=weights_column, validation_frame=validation_frame, max_runtime_secs=max_runtime_secs,
# --> 112                     ignored_columns=ignored_columns, model_id=model_id, verbose=verbose)
#     113
#     114
#
# //anaconda3/lib/python3.7/site-packages/h2o/estimators/estimator_base.py in _train(self, x, y, training_frame, offset_column, fold_column, weights_column, validation_frame, max_runtime_secs, ignored_columns, model_id, verbose, extend_parms_fn)
#     118         has_default_training_frame = hasattr(self, 'training_frame') and self.training_frame is not None
#     119         training_frame = H2OFrame._validate(training_frame, 'training_frame',
# --> 120                                             required=self._requires_training_frame() and not has_default_training_frame)
#     121         validation_frame = H2OFrame._validate(validation_frame, 'validation_frame')
#     122         assert_is_type(y, None, int, str)
#
# //anaconda3/lib/python3.7/site-packages/h2o/frame.py in _validate(param, name, required, message)
#     230                 return
#     231         else:
# --> 232             assert_is_type(param, H2OFrame, message=message)
#     233             return param
#     234
#
# //anaconda3/lib/python3.7/site-packages/h2o/utils/typechecks.py in assert_is_type(var, *types, **kwargs)
#     455     vtn = _get_type_name(type(var))
#     456     raise H2OTypeError(var_name=vname, var_value=var, var_type_name=vtn, exp_type_name=etn, message=message,
# --> 457                        skip_frames=skip_frames)
#     458
#     459
#
# H2OTypeError: 'training_frame' must be a valid H2OFrame!

# %%
# # # #encoding the required columns
# # # #encoding bin_3
df2['bin_3'][df2.bin_3=="F"]=0
df2['bin_3'][df2.bin_3=="T"]=1

# # # #encoding bin_4
df2['bin_4'][df2.bin_4=="N"]=0
df2['bin_4'][df2.bin_4=="Y"]=1
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_dummy = df2
# df2

# %%
dummy = pd.get_dummies(df_dummy['nom_0'],prefix = "nom_0")
df_dummy = df_dummy.merge(dummy,left_index=True,right_index=True)
df_dummy = df_dummy.drop(['nom_0'],axis = 1)

# %%
df_dummy

# %%
from sklearn.model_selection import train_test_split
df_dummy.columns

df_x_d = df_dummy.iloc[:,0:86]
df_y_d = df_dummy.iloc[:,86]

x_train_d, x_test_d, y_train_d, y_test_d = train_test_split(df_x_d,df_y_d,
                                                    train_size=0.8,test_size=0.2,
                                                    random_state = 7)

# %%
col2remove= ["nom_5","nom_6","nom_7","nom_8","nom_9","ord_5"]
cols =[]
for i in columns_to_use:
    if i not in col2remove:
        cols.append(i)

# %%
cols2 = ['nom_1',
     'nom_2',
     'nom_3',
     'nom_4',
     'ord_1',
     'ord_2',
     'ord_3',
     'ord_4',]
for i in cols2:
    dummy = pd.get_dummies(df_dummy[i],prefix = f"{i}")
    df_dummy = df_dummy.merge(dummy,left_index=True,right_index=True)
    df_dummy = df_dummy.drop([i],axis = 1)
# df_dummy

# %%
df2.ord_2.unique()
columns_titles = ['id', 'bin_0', 'bin_1', 'bin_2', 'bin_3', 'bin_4', 'ord_0', 'day',
       'month', 'nom_0_Blue', 'nom_0_Green', 'nom_0_Red',
       'nom_1_Circle', 'nom_1_Polygon', 'nom_1_Square', 'nom_1_Star',
       'nom_1_Trapezoid', 'nom_1_Triangle', 'nom_2_Axolotl', 'nom_2_Cat',
       'nom_2_Dog', 'nom_2_Hamster', 'nom_2_Lion', 'nom_2_Snake',
       'nom_3_Canada', 'nom_3_China', 'nom_3_Costa Rica', 'nom_3_Finland',
       'nom_3_India', 'nom_3_Russia', 'nom_4_Bassoon', 'nom_4_Oboe',
       'nom_4_Piano', 'nom_4_Theremin', 'ord_1_Contributor', 'ord_1_Expert',
       'ord_1_Grandmaster', 'ord_1_Master', 'ord_1_Novice',
       'ord_2_Boiling Hot', 'ord_2_Cold', 'ord_2_Freezing', 'ord_2_Hot',
       'ord_2_Lava Hot', 'ord_2_Warm', 'ord_3_a', 'ord_3_b', 'ord_3_c',
       'ord_3_d', 'ord_3_e', 'ord_3_f', 'ord_3_g', 'ord_3_h', 'ord_3_i',
       'ord_3_j', 'ord_3_k', 'ord_3_l', 'ord_3_m', 'ord_3_n', 'ord_3_o',
       'ord_4_A', 'ord_4_B', 'ord_4_C', 'ord_4_D', 'ord_4_E', 'ord_4_F',
       'ord_4_G', 'ord_4_H', 'ord_4_I', 'ord_4_J', 'ord_4_K', 'ord_4_L',
       'ord_4_M', 'ord_4_N', 'ord_4_O', 'ord_4_P', 'ord_4_Q', 'ord_4_R',
       'ord_4_S', 'ord_4_T', 'ord_4_U', 'ord_4_V', 'ord_4_W', 'ord_4_X',
       'ord_4_Y', 'ord_4_Z','target']
df_dummy=df_dummy.reindex(columns=columns_titles)

# %%
from sklearn.model_selection import train_test_split
df_dummy.columns

df_x_d = df_dummy.iloc[:,0:86]
df_y_d = df_dummy.iloc[:,86]

x_train_d, x_test_d, y_train_d, y_test_d = train_test_split(df_x_d,df_y_d,
                                                    train_size=0.8,test_size=0.2,
                                                    random_state = 7)

df_x_d.shape

# %%
#gradient boosting without oversampling-default parameters-81.53
from sklearn.metrics import accuracy_score
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier()
gbc_model = gbc.fit(x_train_d,y_train_d)
pred_gb = gbc_model.predict(x_test_d)
accuracy_score(y_test_d, pred_gb, normalize=True, sample_weight=None)

# %%
#gradient boosting without oversampling-tuned parameters-81.71
from sklearn.metrics import accuracy_score
from sklearn.ensemble import GradientBoostingClassifier
gbc_hyper = GradientBoostingClassifier(min_samples_split=500,min_samples_leaf=250,
                                max_features=24,learning_rate=0.2,subsample=0.8,
                                n_estimators=500,verbose=1,presort=True)
gbc_model_hyper = gbc_hyper.fit(x_train_d,y_train_d)
pred_gb_hyper = gbc_model_hyper.predict(x_test_d)
accuracy_score(y_test_d, pred_gb_hyper, normalize=True, sample_weight=None)

# %%
#gradient boosting with oversampling-default parameters-81.47
x_s,y_s = sm.fit_resample(x_train_d,y_train_d)
from sklearn.metrics import accuracy_score
from sklearn.ensemble import GradientBoostingClassifier
gbc_over = GradientBoostingClassifier()
gbc_model_over = gbc_over.fit(x_s,y_s)
pred_gb_over = gbc_model_over.predict(x_test_d)
accuracy_score(y_test_d, pred_gb_over, normalize=True, sample_weight=None)

# %%
#gradient boosting with oversampling-tuning parameters-81.7
# x_s,y_s = sm.fit_resample(x_train_d,y_train_d)
from sklearn.metrics import accuracy_score
from sklearn.ensemble import GradientBoostingClassifier
gbc_over_hyper = GradientBoostingClassifier(min_samples_split=500,min_samples_leaf=250,
                                max_features=24,learning_rate=0.2,subsample=0.8,
                                n_estimators=500,verbose=1,presort=True)
gbc_model_over_hyper = gbc_over_hyper.fit(x_s,y_s)
pred_gb_over_hyper = gbc_model_over_hyper.predict(x_test_d)
accuracy_score(y_test_d, pred_gb_over_hyper, normalize=True, sample_weight=None)

# %%
# #randomized search CV
# from sklearn.model_selection import RandomizedSearchCV
# from scipy.stats import uniform, truncnorm, randint
# model_params = {
#     # randomly sample numbers from 4 to 204 estimators
#     'n_estimators': randint(100,1000),
# #     # normally distributed max_features, with mean .25 stddev 0.1, bounded between 0 and 1
# #     'max_features': truncnorm(a=0, b=1, loc=0.25, scale=0.1),
#     # uniform distribution from 0.01 to 0.2 (0.01 + 0.199)
#     'min_samples_split': randint(100,500)
# }
# from sklearn.ensemble import RandomForestClassifier
# rf_m = RandomForestClassifier(max_features=24)
# clf = RandomizedSearchCV(rf_m, model_params, n_iter=100, cv=5, random_state=1)

# # train the random search meta-estimator to find the best model out of 100 candidates
# rf_model_hyper_cv = clf.fit(x_train_d,y_train_d)
# pred_rf_hyper_cv = rf_model_hyper_cv.predict(x_test_d)
# accuracy_score(y_test_d, pred_rf_hyper_cv, normalize=True, sample_weight=None)

# %%
pip install imblearn

# %%
#we will perform oversampling using SMOTE
# import imblearn
from imblearn.over_sampling import SMOTE 
sm = SMOTE(random_state=42)
X_res, y_res = sm.fit_resample(df_x_d,df_dummy.iloc[:,86])

# %%
#linear model prediction accuracy using full feature set-81.47
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm_model = lm.fit(df_x_d,df_y_d)
# pred_lm = lm_model.predict(x_test_d)

# %%
pred_lm[pred_lm>0.5]=1
pred_lm[pred_lm<0.5]=0
pred_lm

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test_d, pred_lm, normalize=True, sample_weight=None)

# %%
#inference-feature selection using Recursive feature elimination reduces the accuracy by a fraction
from sklearn.feature_selection import RFE
rfe_ml = RFE(lm,20)
#transforming training data to RFE format
X_rfe = rfe_ml.fit_transform(x_train_d,y_train_d)  
#test data transformation
X_rfe_test = rfe_ml.fit_transform(x_test_d,y_test_d)

# %%
#prediction using reduced feature set
rfe_model = lm_model.fit(X_rfe,y_train_d)
pred_lm_rfe = rfe_model.predict(X_rfe_test)
# X_rfe.shape
pred_lm_rfe[pred_lm_rfe>0.5]=1
pred_lm_rfe[pred_lm_rfe<0.5]=0
accuracy_score(y_test_d, pred_lm_rfe, normalize=True, sample_weight=None)

# %%
#logistic model accuracy with full feature set-81.294
from sklearn.linear_model import LogisticRegression
Log_reg = LogisticRegression(penalty='l2', dual=False, tol=0.0001)
log_model = Log_reg.fit(df_x_d,df_y_d)
# pred_log = log_model.predict(x_test_d)

# %%
accuracy_score(y_test_d, pred_log, normalize=True, sample_weight=None)

# %%
#transforming data into 20 best features for logistic regression
rfe_log = RFE(Log_reg,20)
X_rfe_train_log = rfe_log.fit_transform(x_train_d,y_train_d)
X_rfe_test_log = rfe_log.fit_transform(x_test_d,y_test_d)

# %%
#logistic reg prediction using reduced feature set-no change in accuracy
rfe_model_log = rfe_log.fit(X_rfe_train_log,y_train_d)
pred_log_rfe = rfe_model_log.predict(X_rfe_test_log)
accuracy_score(y_test_d, pred_log_rfe, normalize=True, sample_weight=None)

# %%
#perceptron classification accuracy same as Logistic-81.294
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(hidden_layer_sizes=10, activation='relu', solver='adam', alpha=0.0001)
mlp_model = mlp.fit(x_train_d,y_train_d)
pred_mlp = mlp_model.predict(x_test_d)

# %%
accuracy_score(y_test_d, pred_mlp, normalize=True, sample_weight=None)

# %%
#Random forest model prediction accuracy using full feature set-81.44
from sklearn.ensemble import RandomForestClassifier
rf_m = RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='auto')
rf_model = rf_m.fit(df_x_d,df_y_d)
# pred_rf = rf_model.predict(x_test_d)

# %%
accuracy_score(y_test_d, pred_rf, normalize=True, sample_weight=None)

# %%
#let go -nom_5,nom_6,nom_7,nom_8,nom_9
df.nom_2.value_counts()

# %%
df_imp = imputer.transform(df)

# %%
type(y_train)

# %%
import pandas as pd
df1 = pd.read_csv('test.csv')

# %%
#removal of unnecessary columns
col_names = list(df1.columns)
cols2remove = ['nom_5',"nom_6","nom_7","nom_8","nom_9","ord_5"]
cols=[]
for i in col_names:
    if i not in cols2remove:
        cols.append(i) 
df3 = pd.DataFrame()
for i in cols:
    df3[i] = df1[i]

# %%
#NA replacement
import statistics as stats
for i in cols:
    if sum(df3[i].isnull()>0):
        df3[i] = df3[i].fillna(stats.mode(df3[i]))

# %%
df3["bin_3"][df3["bin_3"]=="F"]=0
df3["bin_3"][df3["bin_3"]=="T"]=1


df3["bin_4"][df3["bin_4"]=="N"]=0
df3["bin_4"][df3["bin_4"]=="Y"]=1

# %%
y_res[y_res==1]

# %%
from matplotlib import pyplot
pyplot.hist(df_dummy.target)
pyplot.scatter(y_res[y_res==0],y_res[y_res==1],
                alpha=0.3)
# len(df_dummy.target[df_dummy.target==0])

# %%
df_dumm = df3
enc = ['nom_0', 'nom_1','nom_2', 'nom_3', 'nom_4','ord_1', 'ord_2', 'ord_3', 'ord_4']
for i in enc:
    dummy = pd.get_dummies(df_dumm[i],prefix = f"{i}")
    df_dumm = df_dumm.merge(dummy,left_index=True,right_index=True)
    df_dumm = df_dumm.drop([i],axis = 1)

# %%
from sklearn.ensemble import RandomForestClassifier#0.52032
rf_m = RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='auto')
rf_model = rf_m.fit(df_x_d,df_y_d)

# %%
from sklearn.neural_network import MLPClassifier#0.50033
mlp = MLPClassifier(solver='lbfgs', alpha=1e-5,
                     hidden_layer_sizes=(5, 2), random_state=1,activation='relu')
model_nn =mlp.fit(df_x_d,df_y_d)

# %%
from sklearn.ensemble import AdaBoostClassifier #0.5386
abc = AdaBoostClassifier()
abc_model = abc.fit(df_x_d,df_y_d)

# %%
# df_x_d = df_dummy.iloc[:,0:86]
# df_y_d = df_dummy.iloc[:,89:]
from sklearn.ensemble import BaggingClassifier#0.5387
# bc = BaggingClassifier()
# bc_model = bc.fit(df_x_d,df_y_d)

# %%
bc_smote = BaggingClassifier()#0.5327
bc_model_smote = bc_smote.fit(X_res,y_res)

# %%
# pred_bc_smote = bc_model_smote.predict(df_dumm)
savetxt('cats_bc_smote.csv', pred_bc_smote, delimiter=',')

# %%
# df_dumm = df_dumm.iloc[:,0:87]
df_dumm.shape
pred_bc = bc_model.predict(df_dumm)

# %%
from numpy import savetxt
savetxt('cats_bc.csv', pred_bc, delimiter=',')

# %%
# from sklearn.ensemble import RandomForestClassifier
# rf_m = RandomForestClassifier(n_estimators=1000, criterion='gini', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='auto')
# rf_model = rf_m.fit(x_train_d,y_train_d)
pred_abc = abc_model.predict(df_dumm)

# %%
from sklearn.ensemble import ExtraTreesClassifier
ET = ExtraTreesClassifier()
et_model = ET.fit(df_x_d,df_y_d)
pred_ET = et_model.predict(df_dumm)
savetxt('cats_ET.csv', pred_ET, delimiter=',')

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier()
gbc_model = gbc.fit(df_x_d,df_y_d)
pred_gb = gbc_model.predict(df_dumm)
savetxt('cats_gb.csv', pred_gb, delimiter=',')

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier()
KNN_model = KNN.fit(df_x_d,df_y_d)
pred_KNN = KNN_model.predict(df_dumm)
savetxt('cats_KNN.csv', pred_KNN, delimiter=',')

# %%
from numpy import savetxt
# savetxt('cats_abc.csv', pred_abc, delimiter=',')

# %%
linear_values = lm_model.predict(df_x_d)

# %%
# df_dummy['linear_results'] = linear_values
# df_dummy.columns
x = ['id', 'bin_0', 'bin_1', 'bin_2', 'bin_3', 'bin_4', 'ord_0', 'day',
       'month', 'nom_0_Blue', 'nom_0_Green', 'nom_0_Red', 'nom_1_Circle',
       'nom_1_Polygon', 'nom_1_Square', 'nom_1_Star', 'nom_1_Trapezoid',
       'nom_1_Triangle', 'nom_2_Axolotl', 'nom_2_Cat', 'nom_2_Dog',
       'nom_2_Hamster', 'nom_2_Lion', 'nom_2_Snake', 'nom_3_Canada',
       'nom_3_China', 'nom_3_Costa Rica', 'nom_3_Finland', 'nom_3_India',
       'nom_3_Russia', 'nom_4_Bassoon', 'nom_4_Oboe', 'nom_4_Piano',
       'nom_4_Theremin', 'ord_1_Contributor', 'ord_1_Expert',
       'ord_1_Grandmaster', 'ord_1_Master', 'ord_1_Novice',
       'ord_2_Boiling Hot', 'ord_2_Cold', 'ord_2_Freezing', 'ord_2_Hot',
       'ord_2_Lava Hot', 'ord_2_Warm', 'ord_3_a', 'ord_3_b', 'ord_3_c',
       'ord_3_d', 'ord_3_e', 'ord_3_f', 'ord_3_g', 'ord_3_h', 'ord_3_i',
       'ord_3_j', 'ord_3_k', 'ord_3_l', 'ord_3_m', 'ord_3_n', 'ord_3_o',
       'ord_4_A', 'ord_4_B', 'ord_4_C', 'ord_4_D', 'ord_4_E', 'ord_4_F',
       'ord_4_G', 'ord_4_H', 'ord_4_I', 'ord_4_J', 'ord_4_K', 'ord_4_L',
       'ord_4_M', 'ord_4_N', 'ord_4_O', 'ord_4_P', 'ord_4_Q', 'ord_4_R',
       'ord_4_S', 'ord_4_T', 'ord_4_U', 'ord_4_V', 'ord_4_W', 'ord_4_X',
       'ord_4_Y', 'ord_4_Z', 'linear_results','target']
df_dummy=df_dummy.reindex(columns=x)

# %%
#training data after using LM results with logistic regression

df_dummy.columns
df_x_d = df_dummy.iloc[:,0:87]
df_y_d = df_dummy.iloc[:,87:]
from sklearn.linear_model import LogisticRegression
Log_reg = LogisticRegression(penalty='l2', dual=False, tol=0.001)

log_model_afterLM = Log_reg.fit(df_x_d,df_y_d)

# %%
logistic_val = log_model_afterLM.predict(df_x_d)

# %%
df_dummy['logistic_results'] = logistic_val
df_dummy.columns

# %%
y = ['id', 'bin_0', 'bin_1', 'bin_2', 'bin_3', 'bin_4', 'ord_0', 'day',
       'month', 'nom_0_Blue', 'nom_0_Green', 'nom_0_Red', 'nom_1_Circle',
       'nom_1_Polygon', 'nom_1_Square', 'nom_1_Star', 'nom_1_Trapezoid',
       'nom_1_Triangle', 'nom_2_Axolotl', 'nom_2_Cat', 'nom_2_Dog',
       'nom_2_Hamster', 'nom_2_Lion', 'nom_2_Snake', 'nom_3_Canada',
       'nom_3_China', 'nom_3_Costa Rica', 'nom_3_Finland', 'nom_3_India',
       'nom_3_Russia', 'nom_4_Bassoon', 'nom_4_Oboe', 'nom_4_Piano',
       'nom_4_Theremin', 'ord_1_Contributor', 'ord_1_Expert',
       'ord_1_Grandmaster', 'ord_1_Master', 'ord_1_Novice',
       'ord_2_Boiling Hot', 'ord_2_Cold', 'ord_2_Freezing', 'ord_2_Hot',
       'ord_2_Lava Hot', 'ord_2_Warm', 'ord_3_a', 'ord_3_b', 'ord_3_c',
       'ord_3_d', 'ord_3_e', 'ord_3_f', 'ord_3_g', 'ord_3_h', 'ord_3_i',
       'ord_3_j', 'ord_3_k', 'ord_3_l', 'ord_3_m', 'ord_3_n', 'ord_3_o',
       'ord_4_A', 'ord_4_B', 'ord_4_C', 'ord_4_D', 'ord_4_E', 'ord_4_F',
       'ord_4_G', 'ord_4_H', 'ord_4_I', 'ord_4_J', 'ord_4_K', 'ord_4_L',
       'ord_4_M', 'ord_4_N', 'ord_4_O', 'ord_4_P', 'ord_4_Q', 'ord_4_R',
       'ord_4_S', 'ord_4_T', 'ord_4_U', 'ord_4_V', 'ord_4_W', 'ord_4_X',
       'ord_4_Y', 'ord_4_Z', 'linear_results', 'logistic_results','target']
df_dummy=df_dummy.reindex(columns=y)

# %%
df_dummy.columns

# %%
#training data after using LM and logistic results with MLPClassifier
df_x_d = df_dummy.iloc[:,0:88]
df_y_d = df_dummy.iloc[:,88:]
mlp = MLPClassifier(solver='lbfgs', alpha=1e-5,
                     hidden_layer_sizes=(5, 2), random_state=1,activation='relu')
model_mlp =mlp.fit(df_x_d,df_y_d)

# %%
mlp_values = model_mlp.predict(df_x_d)

# %%
df_dummy['mlp_results'] = mlp_values
df_dummy.columns

# %%
z =['id', 'bin_0', 'bin_1', 'bin_2', 'bin_3', 'bin_4', 'ord_0', 'day',
       'month', 'nom_0_Blue', 'nom_0_Green', 'nom_0_Red', 'nom_1_Circle',
       'nom_1_Polygon', 'nom_1_Square', 'nom_1_Star', 'nom_1_Trapezoid',
       'nom_1_Triangle', 'nom_2_Axolotl', 'nom_2_Cat', 'nom_2_Dog',
       'nom_2_Hamster', 'nom_2_Lion', 'nom_2_Snake', 'nom_3_Canada',
       'nom_3_China', 'nom_3_Costa Rica', 'nom_3_Finland', 'nom_3_India',
       'nom_3_Russia', 'nom_4_Bassoon', 'nom_4_Oboe', 'nom_4_Piano',
       'nom_4_Theremin', 'ord_1_Contributor', 'ord_1_Expert',
       'ord_1_Grandmaster', 'ord_1_Master', 'ord_1_Novice',
       'ord_2_Boiling Hot', 'ord_2_Cold', 'ord_2_Freezing', 'ord_2_Hot',
       'ord_2_Lava Hot', 'ord_2_Warm', 'ord_3_a', 'ord_3_b', 'ord_3_c',
       'ord_3_d', 'ord_3_e', 'ord_3_f', 'ord_3_g', 'ord_3_h', 'ord_3_i',
       'ord_3_j', 'ord_3_k', 'ord_3_l', 'ord_3_m', 'ord_3_n', 'ord_3_o',
       'ord_4_A', 'ord_4_B', 'ord_4_C', 'ord_4_D', 'ord_4_E', 'ord_4_F',
       'ord_4_G', 'ord_4_H', 'ord_4_I', 'ord_4_J', 'ord_4_K', 'ord_4_L',
       'ord_4_M', 'ord_4_N', 'ord_4_O', 'ord_4_P', 'ord_4_Q', 'ord_4_R',
       'ord_4_S', 'ord_4_T', 'ord_4_U', 'ord_4_V', 'ord_4_W', 'ord_4_X',
       'ord_4_Y', 'ord_4_Z', 'linear_results', 'logistic_results', 'mlp_results','target']
df_dummy=df_dummy.reindex(columns=z)
df_dummy.columns

# %%
#training data after using LM,logistic and MLP results with random forests
df_x_d = df_dummy.iloc[:,0:89]
df_y_d = df_dummy.iloc[:,89:]
rf_m = RandomForestClassifier(n_estimators=10, criterion='gini', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='auto')
rf_model = rf_m.fit(df_x_d,df_y_d)

# %%
df_dumm['linear_results']=df_dummy['linear_results']
df_dumm['logistic_results']=df_dummy['logistic_results']
df_dumm['mlp_results'] = df_dummy['mlp_results']
rf_value = rf_model.predict(df_dumm)
from numpy import savetxt
savetxt('cats_stacked.csv', rf_value, delimiter=',')
